# %% [markdown]
# # Section: Federated Learning

# %% [markdown]
# # Lesson: Introducing Federated Learning
#
# Federated Learning is a technique for training Deep Learning models on data to which you do not have access. Basically:
#
# Federated Learning: Instead of bringing all the data to one machine and training a model, we bring the model to the data, train it locally, and merely upload "model updates" to a central server.
#
# Use Cases:
#
#     - app company (Texting prediction app)
#     - predictive maintenance (automobiles / industrial engines)
#     - wearable medical devices
#     - ad blockers / autotomplete in browsers (Firefox/Brave)
#
# Challenge Description: data is distributed amongst sources but we cannot aggregated it because of:
#
#     - privacy concerns: legal, user discomfort, competitive dynamics
#     - engineering: the bandwidth/storage requirements of aggregating the larger dataset

# %% [markdown]
# # Lesson: Introducing / Installing PySyft
#
# In order to perform Federated Learning, we need to be able to use Deep Learning techniques on remote machines. This will require a new set of tools. Specifically, we will use an extensin of PyTorch called PySyft.
#
# ### Install PySyft
#
# The easiest way to install the required libraries is with [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/overview.html). Create a new environment, then install the dependencies in that environment. In your terminal:
#
# ```bash
# conda create -n pysyft python=3
# conda activate pysyft # some older version of conda require "source activate pysyft" instead.
# conda install jupyter notebook
# pip install syft
# pip install numpy
# ```
#
# If you have any errors relating to zstd - run the following (if everything above installed fine then skip this step):
#
# ```
# pip install --upgrade --force-reinstall zstd
# ```
#
# and then retry installing syft (pip install syft).
#
# If you are using Windows, I suggest installing [Anaconda and using the Anaconda Prompt](https://docs.anaconda.com/anaconda/user-guide/getting-started/) to work from the command line.
#
# With this environment activated and in the repo directory, launch Jupyter Notebook:
#
# ```bash
# jupyter notebook
# ```
#
# and re-open this notebook on the new Jupyter server.

# %%
# !pip install syft
# !pip install numpy
# Out:
# Requirement already satisfied: syft in /usr/local/lib/python3.6/dist-packages (0.1.20a1)
# Requirement already satisfied: lz4>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from syft) (2.1.10)
# Requirement already satisfied: msgpack>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from syft) (0.6.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from syft) (1.16.4)
# Requirement already satisfied: tf-encrypted>=0.5.4 in /usr/local/lib/python3.6/dist-packages (from syft) (0.5.6)
# Requirement already satisfied: torch>=1.1 in /usr/local/lib/python3.6/dist-packages (from syft) (1.1.0)
# Requirement already satisfied: websockets>=7.0 in /usr/local/lib/python3.6/dist-packages (from syft) (7.0)
# Requirement already satisfied: Flask>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from syft) (1.0.3)
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from syft) (0.3.0)
# Requirement already satisfied: websocket-client>=0.56.0 in /usr/local/lib/python3.6/dist-packages (from syft) (0.56.0)
# Requirement already satisfied: zstd>=1.4.0.0 in /usr/local/lib/python3.6/dist-packages (from syft) (1.4.0.0)
# Requirement already satisfied: flask-socketio>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from syft) (4.1.0)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.6/dist-packages (from syft) (0.21.2)
# Requirement already satisfied: tblib>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from syft) (1.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted>=0.5.4->syft) (5.1.1)
# Requirement already satisfied: tensorflow<2,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted>=0.5.4->syft) (1.14.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=1.0.2->syft) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=1.0.2->syft) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask>=1.0.2->syft) (2.10.1)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask>=1.0.2->syft) (0.15.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->syft) (1.12.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->syft) (4.3.0)
# Requirement already satisfied: python-socketio>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from flask-socketio>=3.3.2->syft) (4.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.0->syft) (0.13.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.0->syft) (1.3.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.14.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (3.7.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.11.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.0.8)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.1.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.33.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.8.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask>=1.0.2->syft) (1.1.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision>=0.3.0->syft) (0.46)
# Requirement already satisfied: python-engineio>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from python-socketio>=2.1.0->flask-socketio>=3.3.2->syft) (3.8.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (41.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.16.4)

# %%
import torch as th

# %%
x = th.tensor([1,2,3,4,5])
x
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
y = x + x

# %%
print(y)
# Out:
# tensor([ 2,  4,  6,  8, 10])

# %%
import syft as sy
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0702 23:29:57.815941 140410069403520 secure_random.py:26] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was '/usr/local/lib/python3.6/dist-packages/tf_encrypted/operations/secure_random/secure_random_module_tf_1.14.0.so'
# W0702 23:29:57.838610 140410069403520 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tf_encrypted/session.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
hook = sy.TorchHook(th)  # this line of code create an instance of th with its backend APIs modified with Syft functions

# %%
th.tensor([1,2,3,4,5]) # notice that Torch functionalities still behave the same
# Out:
# tensor([1, 2, 3, 4, 5])

# %% [markdown]
# # Lesson: Basic Remote Execution in PySyft

# %% [markdown]
# ## PySyft => Remote PyTorch
#
# The essence of Federated Learning is the ability to train models in parallel on a wide number of machines. Thus, we need the ability to tell remote machines to execute the operations required for Deep Learning.
#
# Thus, instead of using Torch tensors - we're now going to work with **pointers** to tensors. Let me show you what I mean. First, let's create a "pretend" machine owned by a "pretend" person - we'll call him Bob.

# %%
bob = sy.VirtualWorker(hook, id="bob") # creates a virtual worker (a simulaion to interface to Bob machines)

# %%
bob._objects
# Out:
# {}

# %%
x = th.tensor([1,2,3,4,5])

# %%
x_ptr =  x.send(bob) # send this data to bob

# %%
bob._objects
# Out:
# {16627761438: tensor([1, 2, 3, 4, 5])}

# %%
x_ptr
# Out:
# (Wrapper)>[PointerTensor | me:23821828811 -> bob:16627761438]

# %%
x.location
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0e68459655e0> in <module>()
# ----> 1 x.location
#
# /usr/local/lib/python3.6/dist-packages/syft/frameworks/torch/hook/hook.py in location(self)
#     782         @property
#     783         def location(self):
# --> 784             return self.child.location
#     785
#     786         tensor_type.location = location
#
# AttributeError: 'Tensor' object has no attribute 'child'

# %%
x.id_at_location

# %%
x.id

# %%
x.owner

# %%
hook.local_worker

# %%
x = x.get()
x

# %%
bob._objects

# %% [markdown]
# # Project: Experience with Remote Tensors
#
# In this project, I want you to .send() and .get() a tensor to TWO workers by calling .send(bob,alice). This will first require the creation of another VirtualWorker called alice.

# %%
# create a second Virtual worker and call it Alice

# %%
# 1 - create some data (a tensor)
# 2- send the data to bob and alice

# %%
# notice what does the send fucntion on two workers return; a multi-pointer
x_ptr

# %%
# what does .child on the pointer object return?
# what does .child.child on the pointer object return?

# %%
# try the .get() on the pointer

# %%
# try the .get(sum_results=True) on your pointer

# %% [markdown]
# # Lesson: Introducing Remote Arithmetic

# %%
x = th.tensor([1,2,3,4,5]).send(bob)
y = th.tensor([1,1,1,1,1]).send(bob)

# %%
x # a pointer to a remote tensor located at bob

# %%
y # a pointer to another remote tensor located at bob

# %%
z = x + y # treat those tensors (i.e., x and y) as local tensors, but they are actually executed remotely
z

# %%
z = z.get()
z

# %%
z = th.add(x,y) # we can also use Torch operation on these tensors to be executed remotely
z

# %%
z = z.get() # yup! same results!
z

# %%
x = th.tensor([1.,2,3,4,5], requires_grad=True).send(bob)
y = th.tensor([1.,1,1,1,1], requires_grad=True).send(bob)

# %%
z = (x + y).sum()
z = z.get()
z

# %%
z.backward()

# %%
x = x.get()

# %%
x

# %%
x.grad

# %% [markdown]
# # Project: Learn a Simple Linear Model
#
# In this project, I'd like for you to create a simple linear model which will solve for the following dataset below. You should use only Variables and .backward() to do so (no optimizers or nn.Modules).
#
# Furthermore, you must do so with both the data and the model being located on Bob's machine.

# %%
import torch as th
import syft as sy

hook = sy.TorchHook(th)  
bob = sy.VirtualWorker(hook, id="bob")

bob

# %%
# create some toy data for our model
input_data = th.tensor([[1.,1],[0.5,1],[1,0],[0,0]], requires_grad=True).send(bob)
output_data = th.tensor([[1.],[1],[0],[0]], requires_grad=True).send(bob)

# %%
# send the data to bob

# %%
# create some linear weights and send them to bob
weights = th.tensor([[0.01],[0.01]], requires_grad = True).send(bob)

# %%
# create a linear model and train it on Bob's machine
# remember how to create a linear model? No? :( 
# Here's the main steps:
#    1- find a prediction
#    2- calcualte the loss (a mean square loss)
#    3- backpropogate using the backword() function
#    4- DO NOT forget to clear your gradients after updating the weights
#    weights.data.sub_(weights.grad * lr)

prediction = input_data.mm(weights)
prediction

# %%
lr = 0.1

for i in range(10):
  prediction = input_data.mm(weights)
  loss = ((prediction - output_data)**2).mean()
  loss.backward()
  weights.data.sub_(weights.grad * lr)
  weights.grad *= 0

  print(loss.get().data)

# %% [markdown]
# # Lesson: Garbage Collection and Common Errors

# %%
bob = bob.clear_objects() # clear the contents of a remote object

# %%
bob._objects

# %%
x = th.tensor([1,2,3,4,5]).send(bob)

# %%
bob._objects

# %%
del x  # delete the pointer to the remote object

# %%
bob._objects

# %%
x.child.garbage_collect_data  # True by default

# %%
x = th.tensor([1,2,3,4,5]).send(bob)

# %%
bob._objects

# %%
x = "asdf"

# %%
bob._objects

# %%
x = th.tensor([1,2,3,4,5]).send(bob)

# %%
x

# %%
bob._objects

# %%
x = "asdf"

# %%
bob._objects  # some error from Jupyter is casuing this to appear!

# %%
del x

# %%
bob._objects

# %%
bob = bob.clear_objects() # erase force 
bob._objects

# %%
for i in range(1000):
    x = th.tensor([1,2,3,4,5]).send(bob)

# %%
bob._objects # notice that there is only a single tensor in bob

# %%
x = th.tensor([1,2,3,4,5]).send(bob)
y = th.tensor([1,1,1,1,1])

# %%
z = x + y

# %%
alice = sy.VirtualWorker(hook, id="alice")
x = th.tensor([1,2,3,4,5]).send(bob)
y = th.tensor([1,1,1,1,1]).send(alice)

# %%
z = x + y

# %% [markdown]
# # Lesson: Toy Federated Learning
#
# Let's start by training a toy model the centralized way. This is about a simple as models get. We first need:
#
# - a toy dataset
# - a model
# - some basic training logic for training a model to fit the data.

# %%
from torch import nn, optim

# %%
# A Toy Dataset
data = th.tensor([[1.,1],[0,1],[1,0],[0,0]], requires_grad=True)
target = th.tensor([[1.],[1], [0], [0]], requires_grad=True)

# %%
# A Toy Model
model = nn.Linear(2,1)

# %%
opt = optim.SGD(params=model.parameters(), lr=0.1)

# %%
def train(iterations=10):
    for iter in range(iterations):
        opt.zero_grad()

        pred = model(data)

        loss = ((pred - target)**2).sum()

        loss.backward()

        opt.step()

        print(loss.data)
        
train()

# %%
# nothing was federated up to this point!

import torch as th
import syft as sy

hook = sy.TorchHook(th)  
bob = sy.VirtualWorker(hook, id="bob")
alice = sy.VirtualWorker(hook, id="alice")

# %%
# create local datasets at Bob and Alice
data_bob = data[0:2].send(bob)
target_bob = target[0:2].send(bob)

data_alice = data[2:4].send(alice)
target_alice = target[2:4].send(alice)

# %%
datasets = [(data_bob, target_bob), (data_alice, target_alice)]
datasets
# Out:
# [((Wrapper)>[PointerTensor | me:9274566982 -> bob:87653307261],
#   (Wrapper)>[PointerTensor | me:17022837444 -> bob:69798472729]),
#  ((Wrapper)>[PointerTensor | me:40752423654 -> alice:25714750206],
#   (Wrapper)>[PointerTensor | me:41280839427 -> alice:32593359363])]

# %%
def train(iterations=1):

    model = nn.Linear(2,1)
    opt = optim.SGD(params=model.parameters(), lr=0.1)
    
    for iter in range(iterations):

        for _data, _target in datasets:

            # send model to the data
            model = model.send(_data.location)
            print(model)

            # do training on the remote machine
            opt.zero_grad()
            pred = model(_data)
            loss = ((pred - _target)**2).sum()
            loss.backward()
            opt.step()

            # get smarter model back
            model = model.get()

            print(loss.get())

# %%
train()
# Out:
# Linear(in_features=2, out_features=1, bias=True)
# tensor(4.8693, requires_grad=True)
# Linear(in_features=2, out_features=1, bias=True)
# tensor(0.0260, requires_grad=True)

# %% [markdown]
# # Lesson: Advanced Remote Execution Tools
#
# In the last section we trained a toy model using Federated Learning. We did this by calling .send() and .get() on our model, sending it to the location of training data, updating it, and then bringing it back. However, at the end of the example we realized that we needed to go a bit further to protect people privacy. Namely, we want to average the gradients BEFORE calling .get(). That way, we won't ever see anyone's exact gradient (thus better protecting their privacy!!!)
#
# But, in order to do this, we need a few more pieces:
#
# - use a pointer to send a Tensor directly to another worker
#
# And in addition, while we're here, we're going to learn about a few more advanced tensor operations as well which will help us both with this example and a few in the future!

# %%
bob.clear_objects()
alice.clear_objects()
# Out:
# <VirtualWorker id:alice #objects:0>

# %%
x = th.tensor([1,2,3,4,5]).send(bob)

# %%
x = x.send(alice)

# %%
bob._objects
# Out:
# {681755396: tensor([1, 2, 3, 4, 5])}

# %%
alice._objects
# Out:
# {59232059007: (Wrapper)>[PointerTensor | alice:59232059007 -> bob:681755396]}

# %%
y = x + x

# %%
y
# Out:
# (Wrapper)>[PointerTensor | me:35076229352 -> alice:14700048988]

# %%
bob._objects
# Out:
# {681755396: tensor([1, 2, 3, 4, 5]), 61259427323: tensor([ 2,  4,  6,  8, 10])}

# %%
alice._objects
# Out:
# {14700048988: (Wrapper)>[PointerTensor | alice:14700048988 -> bob:61259427323],
#  59232059007: (Wrapper)>[PointerTensor | alice:59232059007 -> bob:681755396]}

# %%
jon = sy.VirtualWorker(hook, id="jon")

# %%
bob.clear_objects()
alice.clear_objects()
# Out:
# <VirtualWorker id:alice #objects:0>

# %%
x = th.tensor([1,2,3,4,5]).send(bob).send(alice)
y = th.tensor([1,2,3,4,5]).send(bob).send(jon)

# %%
z = x + y
# Out:
# ---------------------------------------------------------------------------
# TensorsNotCollocatedException             Traceback (most recent call last)
# <ipython-input-20-8c8f78e0676d> in <module>()
# ----> 1 z = x + y
#
# /usr/local/lib/python3.6/dist-packages/syft/frameworks/torch/hook/hook.py in overloaded_native_method(self, *args, **kwargs)
#     672                 # Send the new command to the appropriate class and get the response
#     673                 method = getattr(new_self, method_name)
# --> 674                 response = method(*new_args, **new_kwargs)
#     675
#     676                 # For inplace methods, just directly return self
#
# /usr/local/lib/python3.6/dist-packages/syft/frameworks/torch/hook/hook.py in overloaded_pointer_method(self, *args, **kwargs)
#     503                 if isinstance(args[0], PointerTensor):
#     504                     if args[0].location.id != location.id:
# --> 505                         raise TensorsNotCollocatedException(pointer, args[0], attr)
#     506
#     507             # Send the command
#
# TensorsNotCollocatedException: You tried to call __add__ involving two tensors which are not on the same machine! One tensor is on <VirtualWorker id:alice #objects:1> while the other is on <VirtualWorker id:jon #objects:1>. Use a combination of .move(), .get(), and/or .send() to co-locate them to the same machine.

# %%
x = x.get() # to get the data back
x
# Out:
# (Wrapper)>[PointerTensor | me:59854104348 -> bob:36602545298]

# %%
bob._objects
# Out:
# {36602545298: tensor([1, 2, 3, 4, 5]), 89784608003: tensor([1, 2, 3, 4, 5])}

# %%
alice._objects
# Out:
# {}

# %%
x = x.get()
x
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
bob._objects

# %% [markdown]
# # Lesson: Pointer Chain Operations

# %%
bob.clear_objects()
alice.clear_objects()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e6d0384e691d> in <module>()
# ----> 1 bob.clear_objects()
#       2 alice.clear_objects()
#
# NameError: name 'bob' is not defined

# %%
x = th.tensor([1,2,3,4,5]).send(bob)

# %%
bob._objects
# Out:
# {19293683929: tensor([1, 2, 3, 4, 5])}

# %%
alice._objects
# Out:
# {69469918454: Parameter containing:
#  tensor([0.1062], requires_grad=True), 92854484805: Parameter containing:
#  tensor([[ 0.4030, -0.2205]], requires_grad=True)}

# %%
x_ptr = x.move(alice)

# %%
x_ptr
# Out:
# (Wrapper)>[PointerTensor | me:32402167942 -> alice:32402167942]

# %%
x
# Out:
# (Wrapper)>[PointerTensor | me:64852780419 -> alice:64852780419]

# %%
bob._objects
# Out:
# {}

# %%
alice._objects
# Out:
# {64852780419: tensor([1, 2, 3, 4, 5])}

# %%
bob.clear_objects()
alice.clear_objects()
# Out:
# <VirtualWorker id:alice #objects:0>

# %%
x = th.tensor([1,2,3,4,5]).send(bob).send(alice)

# %%
bob._objects
# Out:
# {81869613150: tensor([1, 2, 3, 4, 5])}

# %%
alice._objects
# Out:
# {99685627431: (Wrapper)>[PointerTensor | alice:99685627431 -> bob:81869613150]}

# %%
x
# Out:
# (Wrapper)>[PointerTensor | me:83688287202 -> alice:99685627431]

# %%
x.remote_get() # inplace operation
# Out:
# (Wrapper)>[PointerTensor | me:83688287202 -> alice:99685627431]

# %%
bob._objects
# Out:
# {}

# %%
alice._objects
# Out:
# {99685627431: tensor([1, 2, 3, 4, 5])}

# %%
x.move(bob)
# Out:
# (Wrapper)>[PointerTensor | me:83688287202 -> bob:83688287202]

# %%
x
# Out:
# (Wrapper)>[PointerTensor | me:83688287202 -> bob:83688287202]

# %%
bob._objects
# Out:
# {83688287202: tensor([1, 2, 3, 4, 5])}

# %%
alice._objects
# Out:
# {}

# %% [markdown]
# **Exercise 1:**
#
# - Create a toy dataset
# - Create a toy linear model
# - Train the dataset using Federated Learning, but do not share the gradiant with the main server, instead use the move function to send the gradients to one of the participating workers, aggregate the model, then send the final model to the main server (i.e., local worker).
#
#
#
# ---
#
#
# **Exercise 2:**
#
# While exercise 1 illustrates a good example of preseving privacy in FL, we still had to expose the gradients to one of the participating workers. To avoid this limitation, you need to send the gradiants to a TRUSTED thirdparty (trusted aggregator) who will aggregate the models and then send the final model to the server (local worker). In this way, we assure that none of the participating workers can access the aggregated model!
#
# 1. create a dataset for each worker (create two)
# 2. create a model for each worker and train it remotely on each worker
# 3. send those two models using the *move()* function to a third worker
# 4. the third workers aggregates the two models (find their mean)
# 5. send the aggregated model to the main server (local worker) using the *get()* function
#
#
#
# ---
#
# To set the weights: `model.weight.set_()`

# %%
# Exercise 1
import syft as sy
import torch as th
from torch import nn, optim
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0703 01:22:42.729575 139999605405568 secure_random.py:26] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow. Fix this by compiling custom ops. Missing file was '/usr/local/lib/python3.6/dist-packages/tf_encrypted/operations/secure_random/secure_random_module_tf_1.14.0.so'
# W0703 01:22:42.745331 139999605405568 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tf_encrypted/session.py:26: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
hook = sy.TorchHook(th)  # this line of code create an instance of th with its backend APIs modified with Syft functions

# %%
# create workers
bob = sy.VirtualWorker(hook, id="bob")
alice = sy.VirtualWorker(hook, id="alice")

# %%
# A Toy Dataset
data = th.tensor([[1.,1],[0,1],[1,0],[0,0]], requires_grad=True)
target = th.tensor([[1.],[1], [0], [0]], requires_grad=True)

# %%
# Send data set to remotes
data_bob = data[0:2].send(bob)
target_bob = target[0:2].send(bob)

data_alice = data[2:4].send(alice)
target_alice = target[2:4].send(alice)

# %%
datasets = [(data_bob, target_bob, alice), (data_alice, target_alice, bob)]
datasets[0][2]
# Out:
# <VirtualWorker id:alice #objects:2>

# %%
# Train the models at each
# worker. Pass the updated
# model to the next worker
def train(iterations=1):
    # Create model
    model = nn.Linear(2,1)
    opt = optim.SGD(params=model.parameters(), lr=0.1)
  
    # send initial model to first worker
    model = model.send(datasets[0][0].location)
    
    for iter in range(iterations):

        for _data, _target, _next_worker in datasets:
            # do training on the remote machine
            opt.zero_grad()
            pred = model(_data)
            loss = ((pred - _target)**2).mean()
            loss.backward()
            opt.step()

            # Move to next worker
            model.move(_next_worker)

            print(loss.get())
            
    # retrieve final model
    model = model.get()
    print(model.weight)

# %%
train(20)
# Out:
# tensor(3.4978, requires_grad=True)
# tensor(0.0548, requires_grad=True)
# tensor(1.1892, requires_grad=True)
# tensor(0.1757, requires_grad=True)
# tensor(0.5265, requires_grad=True)
# tensor(0.2261, requires_grad=True)
# tensor(0.2942, requires_grad=True)
# tensor(0.2218, requires_grad=True)
# tensor(0.1928, requires_grad=True)
# tensor(0.1954, requires_grad=True)
# tensor(0.1388, requires_grad=True)
# tensor(0.1642, requires_grad=True)
# tensor(0.1050, requires_grad=True)
# tensor(0.1349, requires_grad=True)
# tensor(0.0816, requires_grad=True)
# tensor(0.1097, requires_grad=True)
# tensor(0.0642, requires_grad=True)
# tensor(0.0888, requires_grad=True)
# tensor(0.0509, requires_grad=True)
# tensor(0.0717, requires_grad=True)
# tensor(0.0405, requires_grad=True)
# tensor(0.0579, requires_grad=True)
# tensor(0.0322, requires_grad=True)
# tensor(0.0467, requires_grad=True)
# tensor(0.0257, requires_grad=True)
# tensor(0.0377, requires_grad=True)
# tensor(0.0205, requires_grad=True)
# tensor(0.0305, requires_grad=True)
# tensor(0.0164, requires_grad=True)
# tensor(0.0246, requires_grad=True)
# tensor(0.0131, requires_grad=True)
# tensor(0.0199, requires_grad=True)
# tensor(0.0105, requires_grad=True)
# tensor(0.0161, requires_grad=True)
# tensor(0.0084, requires_grad=True)
# tensor(0.0131, requires_grad=True)
# tensor(0.0067, requires_grad=True)
# tensor(0.0106, requires_grad=True)
# tensor(0.0054, requires_grad=True)
# tensor(0.0086, requires_grad=True)
# Parameter containing:
# tensor([[0.0333, 0.8701]], requires_grad=True)

# %% [markdown]
# **Exercise 2:**
#
# While exercise 1 illustrates a good example of preseving privacy in FL, we still had to expose the gradients to one of the participating workers. To avoid this limitation, you need to send the gradiants to a TRUSTED thirdparty (trusted aggregator) who will aggregate the models and then send the final model to the server (local worker). In this way, we assure that none of the participating workers can access the aggregated model!
#
# 1. create a dataset for each worker (create two)
# 2. create a model for each worker and train it remotely on each worker
# 3. send those two models using the *move()* function to a third worker
# 4. the third workers aggregates the two models (find their mean)
# 5. send the aggregated model to the main server (local worker) using the *get()* function
#
#
#
# ---
#
# To set the weights: `model.weight.set_()`

# %%
# create workers
bob = sy.VirtualWorker(hook, id="bob")
alice = sy.VirtualWorker(hook, id="alice")
secureWorker = sy.VirtualWorker(hook, id="secure")

# %%
# Make each worker aware of the other workers
bob.add_workers([alice,secureWorker])
alice.add_workers([bob,secureWorker])
secureWorker.add_workers([bob, alice])
# Out:
# W0703 01:25:35.188226 139999605405568 base.py:628] Worker alice already exists. Replacing old worker which could cause                     unexpected behavior
# W0703 01:25:35.189891 139999605405568 base.py:628] Worker secure already exists. Replacing old worker which could cause                     unexpected behavior
# W0703 01:25:35.191916 139999605405568 base.py:628] Worker bob already exists. Replacing old worker which could cause                     unexpected behavior
# W0703 01:25:35.193211 139999605405568 base.py:628] Worker secure already exists. Replacing old worker which could cause                     unexpected behavior
# W0703 01:25:35.194693 139999605405568 base.py:628] Worker bob already exists. Replacing old worker which could cause                     unexpected behavior
# W0703 01:25:35.198744 139999605405568 base.py:628] Worker alice already exists. Replacing old worker which could cause                     unexpected behavior
# <VirtualWorker id:secure #objects:16>

# %%
# A Toy Dataset
data = th.tensor([[1.,1],[0,1],[1,0],[0,0]], requires_grad=True)
target = th.tensor([[1.],[1], [0], [0]], requires_grad=True)

# %%
# create a linear model at local worker
model = nn.Linear(2,1)

# %%
# Send copies of the linear model to alice and bob
model_bob = model.copy().send(bob)
model_alice = model.copy().send(alice)
aggregator = th.zeros(model.weight.shape).send(secureWorker)

# %%
# Create optimizers for remote workers
opt_bob = optim.SGD(params=model_bob.parameters(), lr=0.1)
opt_alice = optim.SGD(params=model_alice.parameters(), lr=0.1)

# %%
# Send data set to remotes
data_bob = data[0:2].send(bob)
target_bob = target[0:2].send(bob)

data_alice = data[2:4].send(alice)
target_alice = target[2:4].send(alice)

# %%
datasets = [(data_bob, target_bob, model_bob, opt_bob), (data_alice, target_alice, model_alice, opt_alice)]

# %%
# Train model on each train worker
# Move trained models to secure worker
# Aggregate and get to local
def train():
      global aggregator 
      global secureWorker
      global model
    
      # Train
      for _data, _target, _model, _opt in datasets:

          # do training on the remote machine
          _opt.zero_grad()
          pred = _model(_data)
          loss = ((pred - _target)**2).mean()
          loss.backward()
          _opt.step()

          # move trained model to secure
          _model.move(secureWorker)
          
          # Add to aggregator
          aggregator += _model.weight

          print(loss.get())  
          
      # Calculate mean
      aggregator /= len(datasets)
      
      aggregator = aggregator.get()
      
      print(aggregator.data)
      
      model.weight.requires_grad = False
      
      model.weight.set_(aggregator)
      
      model.weight.requires_grad = True

# %%
train()
# Out:
# tensor(0.5798, requires_grad=True)
# tensor(0.0409, requires_grad=True)
# tensor([[-0.1605,  0.4921]])
